# %%
import numpy as np
from GP_regression import * 
import scipy.stats as sc

# %%
GP_titles = ['GP_calib_best/log_L_P1_GP.pickle',\
             'GP_calib_best/log_L_P2_GP.pickle',\
             'GP_calib_best/log_L_P3_GP.pickle'] 
profiles = [1, 2, 3]

GPs = {}

for profile, title in zip(profiles, GP_titles):
    
    GPs[profile] = GPy.load(title)

# %%
bounds = np.array([[0.0, 0.3], [0.35, 0.65], [0.15, 0.45], [0.65, 0.95], [0.05, 0.35]])
LH = LHC(sample_space=0, bounds=bounds,\
         calib_samp=0, GP_samp=500000)

# %%
predict_samples = LH.GP_samp_space

params = {}

for profile in profiles:
    # if (profile == 1 or profile == 3):
    #     continue
    

    log_L_p, V_p = GPs[profile].predict(predict_samples)

    index = int(np.where(log_L_p == np.max(log_L_p))[0])
    print(index)

    params[profile] = predict_samples[index, :]


print(params)
# Out:
# 361191
# 102972
# 3699
# {1: array([0.2247663, 0.5284433, 0.1664427, 0.6547133, 0.3492803]), 2: array([0.2689917, 0.3630623, 0.4224789, 0.8731019, 0.3495653]), 3: array([0.0315321, 0.3624473, 0.1819143, 0.9467015, 0.0571799])}

# %%
res1 = shk_vel(params=params[1], profile=1, plot=True)
res2 = shk_vel(params=params[2], profile=2, plot=True)
res3 = shk_vel(params=params[3], profile=3, plot=True)

print(res1, res2, res3)
# Out:
# [-265.78251934] [-216.90701377] [-397.16571399]

# %%
bounds2 = np.array([[0.04, 0.1], [0.4, 0.55], [0.15, 0.45], [0.8, 0.95], [0.05, 0.35]])

LH2 = LHC(sample_space=0, bounds=bounds2,\
         calib_samp=500, GP_samp=500000)


predict_samples = LH2.GP_samp_space

params = {}

for profile in profiles:
    
    log_L_p, V_p = GPs[profile].predict(predict_samples)

    index = int(np.where(log_L_p == np.max(log_L_p))[0])
    print(index)

    params[profile] = predict_samples[index, :]


print(params)
# Out:
# 22172
# 230359
# 419059
# {1: array([0.05116942, 0.40496035, 0.1521813 , 0.83766905, 0.3492647 ]), 2: array([0.07775962, 0.50005915, 0.2589807 , 0.82328405, 0.2205485 ]), 3: array([0.04000042, 0.54891325, 0.1795947 , 0.94680215, 0.0571637 ])}

# %%
# params[1] = [0.04899034, 0.47255365, 0.1550925, 0.85006655, 0.3485561]

# params[2] = [0.07710526, 0.5420975, 0.3288213, 0.82154435, 0.2182367]

res1 = shk_vel(params=params[1], profile=1, plot=True)
res2 = shk_vel(params=params[2], profile=2, plot=True)
res3 = shk_vel(params=params[3], profile=3, plot=True)

print(res1, res2, res3)
# Out:
# [-276.23341068] [-261.61117832] [-541.49217141]

# %%
theta = [0.1359, 0.3593, 0.2253, 0.7331, 0.1469]

res2 = shk_vel(params=theta, profile=2, plot=True)

# %%
theta = [0.0327, 0.5663, 0.2799, 0.8939, 0.0701]


res3 = shk_vel(params=theta, profile=3, plot=True)

# %%
theta = [0.2715, 0.6257, 0.3933, 0.6737, 0.3185]


res1 = shk_vel(params=theta, profile=1, plot=True)

# %%
print(res1, res2, res3)
# Out:
# [-187.72038344] [-211.0651447] [-468.07058089]

# %%
theta = [0.15844336759714456, 0.40462510458703704, 0.23542729332871637, 0.7175194877671704, 0.1989030947961855]

res2 = shk_vel(params=theta, profile=2, plot=True)

print(res2)
# Out:
# [-241.14173551]
