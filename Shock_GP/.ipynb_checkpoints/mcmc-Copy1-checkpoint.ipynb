# %%
import pickle
from GP_regression import * 
import scipy.stats as st
from scipy.optimize import minimize

# %%
GP_titles = ['GP_calib_best/log_L_P1_GP.pickle',\
             'GP_calib_best/log_L_P2_GP.pickle',\
             'GP_calib_best/log_L_P3_GP.pickle'] 
profiles = [1, 2, 3]

GPs = {}

for profile, title in zip(profiles, GP_titles):
    
    GPs[profile] = GPy.load(title)

# %%
opt_val = {}

opt_res = {}

## nominal values fig 3a

opt_val[1] = np.array([[0.2715, 0.6257, 0.3933, 0.6737, 0.3185]])
opt_res[1] = -187.72038344

## nominal values fig 3b

opt_val[2] = np.array([[0.1359, 0.3593, 0.2253, 0.7331, 0.1469]])
opt_res[2] = -211.0651447


## nominal values fig 4

opt_val[3] = np.array([[0.0315321, 0.3624473, 0.1819143, 0.9467015, 0.0571799]])
opt_res[3] = -397.16571399

# %%
# exp_res = {}

# calib = {}

# exp_res[1] = -107.05880716; exp_res[2] = -110.03513997; exp_res[3] = -54.5520279


# def loss(t, profile):
#     X = t[None, :]
#     gp = GPs[profile]
#     Ef, V = gp.predict(X)
# #     dEf_dx, dV_dx = gp.predict_jacobian(X)
#     L = (Ef[0,0] - exp_res[profile]) ** 2
# #     dL_dx = 2 * (Ef[0,0] - exp_res[profile]) * dEf_dx[0,:,0]
#     return L

# for profile in profiles:
    
#     calib[profile] = minimize(loss, opt_val[profile], args = (profile))['x']

    
# print(calib)

# %%
X_LH = np.load('GP_calib_best/LH_freyja_samples.npy')

results = {}
    
results[1] = np.load('GP_calib_best/Log_L_samples_P1.npy')
results[2] = np.load('GP_calib_best/Log_L_samples_P2.npy')
results[3] = np.load('GP_calib_best/Log_L_samples_P3.npy')

# %%
X = {}
Z = {}
var = {}

for profile in profiles:
    
    X[profile] = np.r_[opt_val[profile], X_LH]
    
    res = np.r_[opt_res[profile], results[profile]]
    
    Z[profile] = res[:, None]
    
    var[profile] = np.r_[np.abs(0.05*opt_res[profile]), np.zeros(X_LH.shape[0])]

# %%
# min_vals = [0.0, 0.35, 0.15, 0.65, 0.05]
# max_vals = [0.3, 0.65, 0.45, 0.95, 0.35]

# %%
X_s = {}

for profile in profiles:
    
    x = X[profile]
    
    min_vals = 0.90 * opt_val[profile][0]; max_vals = 1.1 * opt_val[profile][0]
    scaled = np.zeros_like(x)
    

    for j in range(X_LH.shape[1]):
        
        scaled[:, j] = (x[:, j] - min_vals[j]) / (max_vals[j] - min_vals[j])
    
    X_s[profile] = scaled
    
# print(X_s)

# %%
priors = {}

for profile in profiles:
    
    priors[profile] = [GPy.priors.Gaussian(0.5, 0.5) for x in X_s[profile]]

# %%
def build_gp(x, profile):
    X_s[profile][0, :] = x[:N_param] # set calibration parameters
    kern = GPy.kern.Exponential(input_dim=X_s[profile].shape[1], ARD=True)
    m = GPy.models.GPHeteroscedasticRegression(X_s[profile], Z[profile], kern)
    m.likelihood.variance[:, 0] = var[profile] # fix variances at known values
    m.likelihood.fix()
    m.optimizer_array = m0.optimizer_array # fix hyperparameters at optimized values
    return m

def log_param_priors(x, profile):
    ps = [p.lnpdf(_x) for (_x, p) in zip(x, priors[profile])]
    return np.sum(ps)

def log_post(x, profile):
    m = build_gp(x, profile)
    return m.log_likelihood() + m.log_prior() + log_param_priors(x, profile)

# %%
def grw_metropolis_mcmc(x0, log_h, N, sigma, profile):
    x0 = np.array(x0)
    assert x0.ndim == 1
    d = x0.shape[0]
    X = np.zeros((N+1, d))
    X[0, :] = x0
    accepted = 0
    log_hp = log_h(x0, profile) # previous value of log(h(x))
    
    for i in range(1, N+1):
        # generation
        Xn = X[i-1,:] + sigma*np.random.randn(d)
        
        # calculation 
        log_hn = log_h(Xn, profile)
        alpha = min(1, np.exp(log_hn - log_hp))
        
        # accept/reject
        if np.random.rand() <= alpha:
            X[i, :] = Xn        # accept
            log_hp = log_hn
            accepted += 1
        else:
            X[i, :] = X[i-1, :] # reject
            
    return X, accepted / N

# %%
profile = 1

N_param = 5
N_hyper = 0 # len(m0.optimizer_array)
x0 = np.ones(N_param + N_hyper)
x0[:N_param] = 0.5 # start with the unmodified parameters

X_s[profile][0, :] = x0[:N_param] # set calibration parameters
kern = GPy.kern.Exponential(input_dim=X_s[profile].shape[1], ARD=True)
m0 = GPy.models.GPHeteroscedasticRegression(X_s[profile], Z[profile], kern)
m0.likelihood.variance[:, 0] = var[profile] # fix variances at known values
m0.likelihood.fix()
m0.optimize_restarts(5)
# Out:
#  /home/u1706745/.local/lib/python3.8/site-packages/paramz/transformations.py:111: RuntimeWarning:divide by zero encountered in log
# Optimization restart 1/5, f = 3769.3865697258643
# Optimization restart 2/5, f = 3769.386164299622
# Optimization restart 3/5, f = 3769.386143925358
# Optimization restart 4/5, f = 3769.3861424699207
# Optimization restart 5/5, f = 3769.386152563428
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f200c5b31c0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f200c5cc070>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f200c5bfc40>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f200c5cc910>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f200c5cc0d0>]

# %%
# for sigma_p in [0.1, 0.2, 0.5]:
#     chain, accept = grw_metropolis_mcmc(x0, log_post, 1000, sigma_p, profile=1)
#     print(sigma_p, accept, x0)

# %%
chain, accept = grw_metropolis_mcmc(x0, log_post, 10000, 0.5, profile = profile)
print('acceptance ratio:', accept)
# Out:
#  /home/u1706745/.local/lib/python3.8/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
# acceptance ratio: 0.1565

# %%
parameter_names = [r'$f_e$', r'$f_i$',r'$RA$', r'$C$', r'$LPI$']

plt.plot(chain[1000::10]);
plt.legend(parameter_names);

# %%
print(len(chain))
# Out:
# 10001

# %%
burn = 1000
thin = 20
# log_L_calib = []
# for sample in chain[burn::thin]:
#     m = build_gp(sample, profile=1)
#     Z_p, V_p = m.predict(X_s[1],  Y_metadata={'output_index': np.arange(len(var[1]))[:,None]})
#     log_L_calib.append(Z_p[0, 0])
# log_L_calib = np.array(log_L_calib)

# %%
fig, axs = plt.subplots(1, 5, figsize=(12,4))
for i, ax in enumerate(axs.flat):
    if i >= 5: continue
    ax.acorr(chain[burn::thin, i], detrend=plt.mlab.detrend_mean, maxlags=50, color='C0')
    ax.set_xlim(0, 50)
    ax.hlines([0.5], 0, 50, color='k', ls='dashed')
    ax.set_title(f'$x_{i+1}$ (label)')
fig.subplots_adjust(wspace=0.5)

# %%
fig, axs = plt.subplots(2, 3)
x = np.linspace(0, 1)

min_vals = 0.5 * opt_val[profile][0]; max_vals = 1.5 * opt_val[profile][0]
for j in range(5):
    ax = axs.flat[j]
    x = np.linspace(0.99*min_vals[j], 1.01*max_vals[j], 500)
    sns.histplot(chain[burn::thin, j]*(max_vals[j]-min_vals[j]) + min_vals[j], 
                 stat='density', kde=True, color='C1', ax=ax)
#     u = st.uniform(min_vals[j], max_vals[j]-min_vals[j])
#     ax.plot(x, u.pdf(x), ls='-')    
    ax.set_title(parameter_names[j], fontsize = 25)
    ax.axvline(opt_val[profile][0][j], ls='--', lw=2)
    ax.set_xlabel(r'Value', fontsize = 20)
    ax.set_ylabel(r'Density', fontsize = 20)
plt.subplots_adjust(wspace=0.45, hspace=0.3)
axs.flat[-1].set_visible(False);
plt.show()

# %%
fig, axs = plt.subplots(2, 3)
x = np.linspace(0, 1)
import matplotlib
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

min_vals = 0.5 * opt_val[profile][0]; max_vals = 1.5 * opt_val[profile][0]

ax1 = plt.subplot(2, 3, 1)

x = np.linspace(0.99*min_vals[0], 1.01*max_vals[0], 500)
sns.histplot(chain[burn::thin, 0]*(max_vals[0]-min_vals[0]) + min_vals[0], stat='density', kde=True, lw =2 , color='C1', ax=ax1)
sns.kdeplot(chain[burn::thin, 0]*(max_vals[0]-min_vals[0]) + min_vals[0], color='C1', label = parameter_names[0], lw  = 5, ax = ax1)        
# u = st.uniform(min_vals[0], max_vals[0]-min_vals[0])
# ax1.plot(x, u.pdf(x), ls='-', lw = 3)    
ax1.set_title(parameter_names[0], fontsize = 30)
ax1.axvline(opt_val[profile][0][0], ls='--', lw=5)
ax1.set_xlabel(r'Value', fontsize = 25)
ax1.set_ylabel(r'Density', fontsize = 25)

ax2 = plt.subplot(2, 3, 2)

x = np.linspace(0.99*min_vals[1], 1.01*max_vals[1], 500)
sns.histplot(chain[burn::thin, 1]*(max_vals[1]-min_vals[1]) + min_vals[1], stat='density', kde=True, lw = 2, color='C1', ax=ax2)
sns.kdeplot(chain[burn::thin, 1]*(max_vals[1]-min_vals[1]) + min_vals[1], color='C1', label = parameter_names[1], lw  = 5, ax = ax2)        
# u = st.uniform(min_vals[1], max_vals[1]-min_vals[1])
# ax2.plot(x, u.pdf(x), ls='-', lw = 3)    
ax2.set_title(parameter_names[1], fontsize = 30)
ax2.axvline(opt_val[profile][0][1], ls='--', lw=5)
ax2.set_xlabel(r'Value', fontsize = 25)
ax2.set_ylabel(r'Density', fontsize = 25)

ax3 = plt.subplot(2, 3, 3)

x = np.linspace(0.99*min_vals[2], 1.01*max_vals[2], 500)
sns.histplot(chain[burn::thin, 2]*(max_vals[2]-min_vals[2]) + min_vals[2], stat='density', kde=True, lw =2, color='C1', ax=ax3)
sns.kdeplot(chain[burn::thin, 2]*(max_vals[2]-min_vals[2]) + min_vals[2], color='C1', label = parameter_names[2], lw  = 5, ax = ax3)        
# u = st.uniform(min_vals[2], max_vals[2]-min_vals[2])
# ax3.plot(x, u.pdf(x), ls='-', lw = 3)    
ax3.set_title(parameter_names[2], fontsize = 30)
ax3.axvline(opt_val[profile][0][2], ls='--', lw=5)
ax3.set_xlabel(r'Value', fontsize = 25)
ax3.set_ylabel(r'Density', fontsize = 25)


ax4 = plt.subplot(2, 3, 4)

x = np.linspace(0.99*min_vals[3], 1.01*max_vals[3], 500)
sns.histplot(chain[burn::thin, 3]*(max_vals[3]-min_vals[3]) + min_vals[3], stat='density', kde=True, lw =1, color='C1', ax=ax4)
sns.kdeplot(chain[burn::thin, 3]*(max_vals[3]-min_vals[3]) + min_vals[3], color='C1', label = parameter_names[3], lw  = 3, ax = ax4)        
# u = st.uniform(min_vals[3], max_vals[3]-min_vals[3])
# ax4.plot(x, u.pdf(x), ls='-', lw = 3)    
ax4.set_title(parameter_names[3], fontsize = 30)
ax4.axvline(opt_val[profile][0][3], ls='--', lw=5)
ax4.set_xlabel(r'Value', fontsize = 25)
ax4.set_ylabel(r'Density', fontsize = 25)


ax5 = plt.subplot(2, 3, 5)

x = np.linspace(0.99*min_vals[4], 1.01*max_vals[4], 500)
sns.histplot(chain[burn::thin, 4]*(max_vals[4]-min_vals[4]) + min_vals[4], stat='density', lw = 1, color='C1', ax=ax5)
sns.kdeplot(chain[burn::thin, 4]*(max_vals[4]-min_vals[4]) + min_vals[4], color='C1', label = parameter_names[4], lw  = 3, ax = ax5)        

# u = st.uniform(min_vals[4], max_vals[4]-min_vals[4])
# ax5.plot(x, u.pdf(x), ls='-', lw = 3)    
ax5.set_title(parameter_names[4], fontsize = 30)
ax5.axvline(opt_val[profile][0][4], ls='--', lw=5)
ax5.set_xlabel(r'Value', fontsize = 25)
ax5.set_ylabel(r'Density', fontsize = 25)


plt.subplots_adjust(wspace=0.45, hspace=0.3)
plt.gcf().set_size_inches(30,8)

plt.show()

# %%
# import pandas as pd
# pg = sns.pairplot(pd.DataFrame(chain, columns=parameter_names), plot_kws={'s': 10})
# pg.map_lower(sns.kdeplot);

# %%
fig = plt.figure()

colours = ['C0', 'C1', 'C2', 'C3', 'C4']

index = [0, 1, 2, 3, 4]

peaks = []

for j, C in zip(index, colours):
   
    ax = sns.kdeplot(chain[burn::thin, j]*(max_vals[j]-min_vals[j]) + min_vals[j], color=C, label = parameter_names[j], lw  = 3)        
    # plt.axvline(opt_val[profile][0][j], ls='--', lw=2, color = C, label = r'Optimal GP ' + parameter_names[j])
    plt.xlabel(r'Value', fontsize = 18)
    plt.ylabel(r'Density', fontsize = 18)
    plt.title(r'Profile = '+str(profile), fontsize = 20)
    plt.legend(fontsize = 18)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    x = ax.lines[j].get_xdata() # Get the x data of the distribution
    y = ax.lines[j].get_ydata() # Get the y data of the distribution
    maxid = np.argmax(y) # The id of the peak (maximum of y data)
    peaks.append(x[maxid])
plt.show()

# %%
fig = plt.figure()

colours = ['C0', 'C1', 'C2', 'C3', 'C4']

index = [0, 1, 2, 3, 4]



for j, C in zip(index, colours):
   
    ax = sns.kdeplot(chain[burn::thin, j]*(max_vals[j]-min_vals[j]) + min_vals[j], color=C, label = parameter_names[j] + r' (' + str(np.round(peaks[j],3)) + r')', lw  = 3)        
    # plt.axvline(opt_val[profile][0][j], ls='--', lw=2, color = C, label = r'Optimal GP ' + parameter_names[j])
    plt.xlabel(r'Value', fontsize = 18)
    plt.ylabel(r'Density', fontsize = 18)
    plt.title(r'Profile = '+str(profile), fontsize = 20)
    plt.legend(fontsize = 18)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
#     plt.axvline(x = peaks[j], color = C, lw =3, linestyle = '--')
#     plt.axvline(x =0.06, color = 'black')

plt.xlim(-0.1, 1.8)
plt.show()

# %%
print(peaks)
# Out:
# [0.28966837331774964, 0.6805538993671545, 0.42533024540209885, 0.47852170013770284, 0.24859702408905554]
